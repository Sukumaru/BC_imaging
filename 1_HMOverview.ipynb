# %%
library(NMF)
library(circlize)

# %% [markdown]
# ## Data Loading

# %%
x2 = readRDS(file = "./rds/x2_ISE.rds")
x3_immune_immune = readRDS(file = "./rds/x3_immune_immune.rds")
x3_stromal_stromal = readRDS(file = "./rds/x3_stromal_stromal.rds")
x3_immune_stromal = readRDS(file = "./rds/x3_immune_stromal.rds")
x3_stromal_epithelial = readRDS(file = "./rds/x3_stromal_epithelial.rds")
x3_immune_epithelial_clean = readRDS(file = "./rds/x3_immune_epithelial_clean.rds")
x4_epithelial_epithelial = readRDS(file = "./rds/x4_epithelial_epithelial.rds")

# %% [markdown]
# ## Cellular Phenotypic Features

# %%
## original features
aheatmap(t(x2), color = "-RdBu:50",distfun='pearson', hclustfun ="complete",scale="col")
# Out:
# plot without title

# %% [markdown]
# ## Tumor Microenvironment Features

# %%
png('./1_HMResult/x3_immune_immune.png', width = 12, height = 12, units = 'in',  res=600)
aheatmap(t(x3_immune_immune[,c("T_Cell___T_Cell.1","T_B_Cells___T_B_Cells","Macrophage___Macrophage.1","B_Cell___B_Cell","T_Cell___Macrophage","T_Cell___T_Cell.2","T_B_Cells___T_Cell","B_Cell___T_Cell")]), color = "-RdBu:100", distfun='pearson', hclustfun ="average",scale="column", cellheight = 10)
dev.off()
# Out:
# png
#   2

# %%
png('./1_HMResult/x3_stromal_stromal.png', width = 12, height = 12, units = 'in',  res=600)
aheatmap(t(x3_stromal_stromal[,c("Small_Elongated___Small_Elongated","Vimentin.hi___Vimentin.hi","Fibronectin.hi___Fibronectin.hi","Vimentin.hi___Small_Elongated","Small_Circular___Small_Elongated","Small_Elongated___Fibronectin.hi","Endothelial___Endothelial","SMA_hi_Vimentin___SMA_hi_Vimentin","Endothelial___Small_Elongated","Endothelial___Vimentin.hi","Vimentin.hi___Fibronectin.hi","Small_Circular___Small_Circular","Small_Elongated___SMA_hi_Vimentin","Vimentin.hi___SMA_hi_Vimentin","Vimentin.hi___Small_Circular","Endothelial___Small_Circular","Small_Circular___Fibronectin.hi","Endothelial___SMA_hi_Vimentin","Endothelial___Fibronectin.hi","Small_Circular___SMA_hi_Vimentin","Fibronectin.hi___SMA_hi_Vimentin","Small_Elongated___Large_Elongated","Vimentin.hi___Large_Elongated","Fibronectin.hi___Large_Elongated","Small_Circular___Large_Elongated","Endothelial___Large_Elongated","Large_Elongated___SMA_hi_Vimentin")[1:12]]), color = "-RdBu:100", distfun='pearson', hclustfun ="complete",scale="column", cellheight = 10)
dev.off()
# Out:
# png
#   2

# %%
png('./1_HMResult/x3_immune_stromal.png', width = 12, height = 12, units = 'in',  res=600)
aheatmap(t(x3_immune_stromal[,c("T_Cell___Small_Elongated","T_Cell___Vimentin.hi","T_Cell___Endothelial","Macrophage___Small_Elongated","Macrophage___Vimentin.hi","Macrophage___Fibronectin.hi","T_Cell___Small_Circular","T_Cell___Vimentin.hi.1",
"T_Cell___Fibronectin.hi","T_B_Cells___Small_Elongated","T_B_Cells___Vimentin.hi","Macrophage___Endothelial"
)]), color = "-RdBu:100", distfun='pearson', hclustfun ="complete",scale="column", cellheight = 10)
dev.off()
# Out:
# png
#   2

# %%
png('./1_HMResult/x3_stromal_epithelial.png', width = 12, height = 12, units = 'in',  res=600)
aheatmap(t(x3_immune_epithelial_clean[,c("T_Cell___CK.low_HR.low","T_Cell___CK.low_HR.low.1","T_Cell___CK_HRlow_p53.","T_Cell___Basal_CK","T_Cell___CK._HR.hi","Macrophage___CK.low_HR.low","T_Cell___CK7._CK.","Macrophage___Basal_CK","T_Cell___Apoptotic","Macrophage___CK._HR.hi","T_B_Cells___Myoepithelial","T_Cell___Proliferative","T_Cell___CK7._CKhi_Cadherin","T_Cell___CK._HR.","T_Cell___p53._EGFR.","Macrophage___CK_HRlow_p53.","T_Cell___Epithelial.low","Macrophage___CK7._CK.","Macrophage___Proliferative","T_Cell___CKlow_HR.hi","T_Cell___p53._EGFR..1","Macrophage___CK._HR.","Macrophage___Apoptotic","Macrophage___p53._EGFR.","Macrophage___Epithelial.low","T_B_Cells___CK._HR.hi","Macrophage___CK7._CKhi_Cadherin","T_B_Cells___Basal_CK","B_Cell___p53._EGFR.","B_Cell___CK.low_HR.low","B_Cell___CK._HR.hi","Macrophage___Hypoxic","T_B_Cells___Epithelial.low","T_Cell___Proliferative.1","T_Cell___Hypoxic","T_Cell___CK._HR.hi.1","Macrophage___CKlow_HR.hi","T_B_Cells___CK7._CK.","T_B_Cells___CK.low_HR.low","B_Cell___Basal_CK","T_Cell___Myoepithelial","T_B_Cells___CK_HRlow_p53.","T_Cell___CK._HR..1","B_Cell___CK_HRlow_p53.","B_Cell___CK7._CKhi_Cadherin","T_Cell___CK7._CKhi_Cadherin.1","T_Cell___CKlow_HR.hi.1","B_Cell___Proliferative","T_B_Cells___CK._HR.","B_Cell___CK._HR.","B_Cell___Apoptotic","T_Cell___Basal_CK.1","Macrophage___Myoepithelial","T_B_Cells___Proliferative","B_Cell___Myoepithelial","T_Cell___CK7._CK..1","T_Cell___Hypoxic.1","T_B_Cells___Apoptotic","T_Cell___CK_HRlow_p53..1","T_Cell___Apoptotic.1","T_Cell___Epithelial.low.1","T_B_Cells___p53._EGFR.","B_Cell___CK7._CK.","Macrophage___Proliferative.1","T_B_Cells___CK7._CKhi_Cadherin","Macrophage___Basal_CK.1","B_Cell___Epithelial.low","B_Cell___Hypoxic","Macrophage___CK.low_HR.low.1","T_B_Cells___CKlow_HR.hi","T_B_Cells___Hypoxic","Macrophage___Apoptotic.1","T_Cell___Myoepithelial.1","Macrophage___CK7._CK..1","Macrophage___CK_HRlow_p53..1","B_Cell___CKlow_HR.hi","Macrophage___Myoepithelial.1","Macrophage___Epithelial.low.1","Macrophage___CK._HR..1","Macrophage___CK._HR.hi.1","Macrophage___CKlow_HR.hi.1","Macrophage___p53._EGFR..1")[1:20]]), color = "-RdBu:100", distfun='pearson', hclustfun ="complete",scale="column", cellheight = 10)
dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Tumor Core Interaction features

# %%
png('./1_HMResult/x4_epithelial_epithelial.png', width = 12, height = 12, units = 'in',  res=600)
aheatmap(t(x4_epithelial_epithelial[,c("CK_HRlow_p53.___CK_HRlow_p53.","CK.low_HR.low___CK.low_HR.low","CK._HR.hi___CK._HR.hi","CK7._CKhi_Cadherin___CK7._CKhi_Cadherin","CK7._CK.___CK7._CK.","CK._HR.___CK._HR.","Apoptotic___Apoptotic","Epithelial.low___Epithelial.low",
"CKlow_HR.hi___CKlow_HR.hi","Proliferative___Proliferative","Basal_CK___Basal_CK","p53._EGFR.___p53._EGFR.","Hypoxic___Hypoxic","Myoepithelial___Myoepithelial","CK._HR.hi___CK_HRlow_p53.","CK.low_HR.low___CK_HRlow_p53.",
"CK.low_HR.low___CK._HR.hi","Epithelial.low___CK_HRlow_p53.")]), color = "-RdBu:100", distfun='pearson', hclustfun ="complete",scale="column", cellheight = 10)
dev.off()
# Out:
# png
#   2
