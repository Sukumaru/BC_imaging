# %%
library(NMF)
# Out:
# Loading required package: pkgmaker
#
# Loading required package: registry
#
# Loading required package: rngtools
#
# Loading required package: cluster
#
# NMF - BioConductor layer [OK] | Shared memory capabilities [NO: bigmemory] | Cores 39/40
#
#   To enable shared memory capabilities, try: install.extras('
# NMF
# ')

# %% [markdown]
# ## Data Loading

# %%
xfnorm = readRDS(file = "./rds/xfnorm.rds")
nfeat_brunet_rs30_estim.r =  readRDS("./rds/NMFResult.rds")

# %% [markdown]
# ## Model Fitting

# %%
# nfeat_brunet_rs30_estim.r = nmf(xf_norm, 3:15, nruns=30, seed='random')

# %% [markdown]
# ## Results

# %%
plot(nfeat_brunet_rs30_estim.r)
# Out:
# plot without title

# %% [markdown]
# ### linkage methods- average, ward, single, complete, mcquitty, centroid
# ### results for nmf_brunet_0_runs30_estim.r

# %%
cophcor(nfeat_brunet_rs30_estim.r$fit$`3`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`4`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`5`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`6`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`7`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`8`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`9`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`11`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`12`, linkage = "average")
# Out:
# [1] 0.8659423
# [1] 0.9010071
# [1] 0.8979475
# [1] 0.9090558
# [1] 0.9061857
# [1] 0.92361
# [1] 0.9423792
# [1] 0.9511009
# [1] 0.9615362
# [1] 0.9550895

# %%
cophcor(nfeat_brunet_rs30_estim.r$fit$`3`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`4`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`5`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`6`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`7`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`8`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`9`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`11`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`12`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`13`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`14`, linkage = "average")
cophcor(nfeat_brunet_rs30_estim.r$fit$`15`, linkage = "average")
# Out:
# [1] 0.8030099
# [1] 0.836713
# [1] 0.8786555
# [1] 0.8781601
# [1] 0.8939881
# [1] 0.8986995
# [1] 0.9469618
# [1] 0.9614898
# [1] 0.9509091
# [1] 0.949956
# [1] 0.9408275
# [1] 0.9545973
# [1] 0.9529728

# %%
cophcor(nfeat_brunet_rs30_estim.r$fit$`3`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`4`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`5`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`6`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`7`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`8`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`9`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`11`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`12`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`13`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`14`, linkage = "ward.D2")
cophcor(nfeat_brunet_rs30_estim.r$fit$`15`, linkage = "ward.D2")
# Out:
# [1] 0.7284008
# [1] 0.7488478
# [1] 0.7983402
# [1] 0.7737082
# [1] 0.8249335
# [1] 0.8080781
# [1] 0.8592673
# [1] 0.8779644
# [1] 0.8779218
# [1] 0.888241
# [1] 0.8699194
# [1] 0.8871433
# [1] 0.844027

# %%
cophcor(nfeat_brunet_rs30_estim.r$fit$`3`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`4`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`5`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`6`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`7`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`8`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`9`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`11`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`12`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`13`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`14`, linkage = "single")
cophcor(nfeat_brunet_rs30_estim.r$fit$`15`, linkage = "single")
# Out:
# [1] 0.5229192
# [1] 0.5369633
# [1] 0.7099511
# [1] 0.6724858
# [1] 0.7041943
# [1] 0.7287167
# [1] 0.810027
# [1] 0.8873096
# [1] 0.7700665
# [1] 0.6888584
# [1] 0.7859981
# [1] 0.8037281
# [1] 0.6967262

# %%
cophcor(nfeat_brunet_rs30_estim.r$fit$`3`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`4`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`5`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`6`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`7`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`8`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`9`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`11`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`12`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`13`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`14`, linkage = "complete")
cophcor(nfeat_brunet_rs30_estim.r$fit$`15`, linkage = "complete")
# Out:
# [1] 0.7311718
# [1] 0.772448
# [1] 0.7766887
# [1] 0.7885757
# [1] 0.8436994
# [1] 0.8534916
# [1] 0.9179302
# [1] 0.9355527
# [1] 0.893985
# [1] 0.8751615
# [1] 0.8890697
# [1] 0.9024909
# [1] 0.911692

# %%
cophcor(nfeat_brunet_rs30_estim.r$fit$`15`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`3`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`4`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`5`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`6`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`7`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`8`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`9`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`11`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`12`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`13`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`14`, linkage = "mcquitty")
cophcor(nfeat_brunet_rs30_estim.r$fit$`15`, linkage = "mcquitty")
# Out:
# [1] 0.92414
# [1] 0.9338191
# [1] 0.7611679
# [1] 0.7673703
# [1] 0.8549233
# [1] 0.7805484
# [1] 0.8169579
# [1] 0.8574896
# [1] 0.9160442
# [1] 0.9338191
# [1] 0.9275481
# [1] 0.9205708
# [1] 0.897797
# [1] 0.9133823
# [1] 0.92414

# %%
cophcor(nfeat_brunet_rs30_estim.r$fit$`3`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`4`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`5`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`6`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`7`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`8`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`9`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`11`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`12`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`13`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`14`, linkage = "centroid")
cophcor(nfeat_brunet_rs30_estim.r$fit$`15`, linkage = "centroid")
# Out:
# [1] 0.7504434
# [1] 0.8037033
# [1] 0.8508268
# [1] 0.8357193
# [1] 0.8206889
# [1] 0.8564278
# [1] 0.9064519
# [1] 0.9314203
# [1] 0.9145793
# [1] 0.8991524
# [1] 0.9050076
# [1] 0.8849292
# [1] 0.8982082

# %%
cophcor(nfeat_brunet_rs30_estim.r$fit$`3`, linkage = "median")
cophcor(nfeat_brunet_rs30_estim.r$fit$`4`, linkage = "median")
cophcor(nfeat_brunet_rs30_estim.r$fit$`5`, linkage = "median")
cophcor(nfeat_brunet_rs30_estim.r$fit$`6`, linkage = "median")
cophcor(nfeat_brunet_rs30_estim.r$fit$`7`, linkage = "median")
cophcor(nfeat_brunet_rs30_estim.r$fit$`8`, linkage = "median")
cophcor(nfeat_brunet_rs30_estim.r$fit$`9`, linkage = "median")
cophcor(nfeat_brunet_rs30_estim.r$fit$`10`, linkage = "median")
# Out:
# [1] 0.726685
# [1] 0.7802146
# [1] 0.692874
# [1] 0.5842702
# [1] 0.7161536
# [1] 0.7163746
# [1] 0.7630435
# [1] 0.6610644

# %%
plot(nmf_brunet_0_runs30_estim.r,'silhouette.consensus')
# Out:
# plot without title

# %%
############## silhoette coefficients
# [1] 0.6113480 0.5410899 0.4912990 0.5737002 0.7449374 0.6742516
# [7] 0.4932353 0.5366065 0.4648228 0.4333548 0.3630246 0.3593396
# [13] 0.3416724

# %% [markdown]
# ##  Best Result with ncluster=7

# %%
consensusmap(nmf_brunet_0_runs30_estim.r$fit$`7`, hclustfun = "average")
# Out:
# plot without title

# %%
consensusmap(nmf_brunet_0_runs30_estim.r$fit$`7`, hclustfun = "ward")
# Out:
# The "ward" method has been renamed to "ward.D"; note new "ward.D2"
#
# Warning message in atrack(annCol, order = res$colInd, .SPECIAL = specialAnnotation(2L), :
# “Discarding unresolved special annotation tracks: ':basis', ':consensus', ':silhouette'”
# plot without title

# %%
consensusmap(nmf_brunet_0_runs30_estim.r$fit$`7`, hclustfun = "single")
# Out:
# plot without title

# %%
consensusmap(nmf_brunet_0_runs30_estim.r$fit$`7`, hclustfun ="complete")
# Out:
# Warning message in atrack(annCol, order = res$colInd, .SPECIAL = specialAnnotation(2L), :
# “Discarding unresolved special annotation tracks: ':basis', ':consensus', ':silhouette'”
# plot without title

# %% [markdown]
# ## Clustering Results

# %%
basismap(nmf_brunet_0_runs30_estim.r$fit$`7`)
# Out:
# plot without title

# %%
# Pick the largest value
coef(nmf_brunet_0_runs30_estim.r$fit$`7`)
# Out:
#      [,1]         [,2]         [,3]         [,4]         [,5]
# [1,] 0.0073498590 6.263402e-03 4.578749e-03 2.220446e-16 5.385645e-03
# [2,] 0.0177373280 1.193752e-02 2.220446e-16 2.220446e-16 2.220446e-16
# [3,] 0.0002050725 7.455950e-05 2.220446e-16 2.622603e-05 1.439772e-04
# [4,] 0.0003076261 4.666265e-04 2.220446e-16 2.220446e-16 2.984138e-05
# [5,] 0.0044374828 7.149139e-03 7.906849e-03 6.389249e-03 1.070336e-02
# [6,] 0.0058886465 9.980637e-03 9.544915e-03 6.591784e-03 2.220446e-16
# [7,] 0.0078344284 2.220446e-16 2.220446e-16 6.780786e-03 5.731819e-03
#      [,6]         [,7]         [,8]         [,9]         [,10]        [,11]
# [1,] 5.100466e-03 5.595949e-03 4.737979e-03 0.0065446051 6.353800e-03 ⋯
# [2,] 2.220446e-16 6.843396e-03 2.220446e-16 0.0158070043 2.220446e-16 ⋯
# [3,] 1.508110e-05 4.033671e-03 2.220446e-16 0.0003522975 8.036181e-05 ⋯
# [4,] 8.320319e-05 2.629347e-05 1.608231e-04 0.0013535751 2.203736e-04 ⋯
# ...

# %%
ind_subset = c(2,2,6,4,5,5,2,5,2,6,3,5,1,5,5,6,2,5,2,5,2,5,7,7,2,7,2,3,1,6,5,6,2,2,2,6,1,2,2,2,6,2,3,5,6,2,2,5,2,6,2,6,2,1,5,2,4,2,2,6,4,2,2,5,3,1,6,5,2,5,1,3,6,2,6,5,7,6,5,5,3,2,2,5,5,2,5,2,6,2,6,2,6,5,5,6,3,7,2,2,4,6,5,5,6,6,4,5,4,6,5,1,6,5,1,7,6,7,3,6,2,6,6,6,7,5,6,2,5,6,3,2,7,5,6,5,5,6,2,5,1,6,5,5,2,2,2,6,5,7,6,3,7,1,7,2,1,2,6,5,4,5,6,7,5,6,2,6,3,5,2,6,7,6,4,1,2,6,6,5,1,7,2,6,2,1,6,2,6,2,6,6,6,6,5,2,7,6,2,6,3,2,6,1,2,6,2,1,7,6,5,1,6,5,6,6,5,6,6,6,7,6,6,2,6,2,6,6,6,1,7,2,1,1,1,6,1,2,7,5,3,1,2,7,6,7,5,6,2,2,6,6,5,5,7,6,6,6,2)

# %% [markdown]
# ## Save Result
